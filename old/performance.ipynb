# %% [markdown]
# # Only pay attention to the pictures of vegatable mask, the others are for myself only
# ## metric used : die coefficient
# ## performance : 0.79 +- 0.14 ,mean +- std
# ###  5 15 25 percentile  : 0.57 0.66 0.73 (measure the lower bound performance)
# ###  50 75 percentile  :  0.83 0.91

# %%
#tbCallBack = tf.keras.callbacks.TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
for epoch in range(5,20,2):
    model.fit_generator(my_LgeneratorV2(L_train,y_train//255, batch_size=16),
                                      epochs =2, validation_data = my_LgeneratorV2(L_val,y_val//255,batch_size=64),
                        validation_steps=len(L_val)//8,
                        verbose = 1, steps_per_epoch=40)
    evaluate(epoch)
# Out:
# Epoch 1/2
# 40/40 [==============================] - 151s 4s/step - loss: 0.1394 - acc: 0.9386 - val_loss: 0.1849 - val_acc: 0.9486
# Epoch 2/2
# 40/40 [==============================] - 126s 3s/step - loss: 0.0545 - acc: 0.9694 - val_loss: 0.0819 - val_acc: 0.9652
# BLACK_W1 LetBC GR7-a2_mask.png
#  0.360557341908
# BLACK_W1 LetGC GR3-a2_mask.png
#  0.653796780883
# BLACK_W2 LetMQ GR8-a2_mask.png
#  0.941737649063
# BLACK_W3 LetTG GR8-a2_mask.png
#  0.746578930824
# MIS_IMG_20180808_104934_mask.png
#  0.838314711884
# MIS_W6 NaiBai GR4-b1_mask.png
#  0.761281364673
# RACK_IMG_20180801_103347_mask.png
#  0.917014534264
# RACK_W3 GR3-c1_mask.png
#  0.750134116745
# RACK_W3 GR4-c1_mask.png
#  0.817598413615
# RACK_W3 GR6-c1.jpg_mask.png
#  0.779570338803
# RED_IMG_20180816_154043_mask.png
#  0.910832807248
# RED_W1 LetMQ GR8-a2_mask.png
#  0.57587776626
# RED_W2 LetBH GR8-a2_mask.png
#  0.667696914087
# RED_W3 LetRC GR4-a2_mask.png
#  0.867745565618
# ...
